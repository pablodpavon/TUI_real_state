# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
# %config IPCompleter.greedy=True

# %%
listings = pd.read_csv('.../listings.csv')
listings.head()
# Out:
#                    id                                               name  \
# 0  652868795892201022  Kleine Auszeit? Oder Business-Trip? Alles mögl...
# 1            27080612  Apartment with Living/Sleeping Room & own Kitchen
# 2            29077694             Wohnung im Grünen nah an der Metropole
# 3  665648367391379321                 Schöne Eigentumswohnung mit Balkon
# 4            37738004              Remise Villa Erica Superior Apartment
#
#      host_id    host_name     neighbourhood_group        neighbourhood  \
# 0   21708794  Familie Sek  Tempelhof - Schöneberg          Lichtenrade
# 1  130216168        Tommy   Marzahn - Hellersdorf            Mahlsdorf
# 2  219116245      Tilmann   Steglitz - Zehlendorf  Zehlendorf  Südwest
# 3  106965422         Paul   Steglitz - Zehlendorf            Drakestr.
# 4   42048631    Archibald   Steglitz - Zehlendorf            Drakestr.
#
#     latitude  longitude        room_type  price  minimum_nights  \
# ...

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16680 entries, 0 to 16679
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              16680 non-null  int64
#  1   name                            16660 non-null  object
#  2   host_id                         16680 non-null  int64
#  3   host_name                       16664 non-null  object
#  4   neighbourhood_group             16680 non-null  object
#  5   neighbourhood                   16680 non-null  object
#  6   latitude                        16680 non-null  float64
#  7   longitude                       16680 non-null  float64
#  8   room_type                       16680 non-null  object
#  9   price                           16680 non-null  int64
#  10  minimum_nights                  16680 non-null  int64
#  11  number_of_reviews               16680 non-null  int64
# ...

# %%
listings_det = pd.read_csv('.../listings.csv.gz')
listings_det.head()
# Out:
#                    id                                      listing_url  \
# 0  652868795892201022  https://www.airbnb.com/rooms/652868795892201022
# 1            29077694            https://www.airbnb.com/rooms/29077694
# 2            27080612            https://www.airbnb.com/rooms/27080612
# 3  665648367391379321  https://www.airbnb.com/rooms/665648367391379321
# 4                3176                https://www.airbnb.com/rooms/3176
#
#         scrape_id last_scraped           source  \
# 0  20220915162225   2022-09-15      city scrape
# 1  20220915162225   2022-09-16  previous scrape
# 2  20220915162225   2022-09-15      city scrape
# 3  20220915162225   2022-09-15      city scrape
# 4  20220915162225   2022-09-15      city scrape
#
#                                                 name  \
# 0  Kleine Auszeit? Oder Business-Trip? Alles mögl...
# 1             Wohnung im Grünen nah an der Metropole
# 2  Apartment with Living/Sleeping Room & own Kitchen
# ...

# %%
listings_det.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16680 entries, 0 to 16679
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            16680 non-null  int64
#  1   listing_url                                   16680 non-null  object
#  2   scrape_id                                     16680 non-null  int64
#  3   last_scraped                                  16680 non-null  object
#  4   source                                        16680 non-null  object
#  5   name                                          16660 non-null  object
#  6   description                                   16367 non-null  object
#  7   neighborhood_overview                         8820 non-null   object
#  8   picture_url                                   16680 non-null  object
# ...

# %%
reviews = pd.read_csv('.../reviews.csv')
reviews.head()
# Out:
#    listing_id        date
# 0        3176  2009-06-20
# 1        3176  2010-11-07
# 2        3176  2010-11-24
# 3        3176  2010-12-21
# 4        3176  2011-01-04

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463168 entries, 0 to 463167
# Data columns (total 2 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   listing_id  463168 non-null  int64
#  1   date        463168 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 7.1+ MB

# %%
reviews_det = pd.read_csv('.../reviews.csv.gz')
reviews_det.head()
# Out:
#    listing_id      id        date  reviewer_id reviewer_name  \
# 0        3176    4283  2009-06-20        21475         Milan
# 1       22438  218181  2011-04-05       401483     Alexandre
# 2        3176  134722  2010-11-07       263467        George
# 3        3176  144064  2010-11-24        76726      Patricia
# 4       22438  247962  2011-05-02       457385           Sam
#
#                                             comments
# 0  excellent stay, i would highly recommend it. a...
# 1  Javier gave us quite a fright when none of his...
# 2  Britta's apartment in Berlin is in a great are...
# 3  Fantastic, large place in good location. Only ...
# 4  We was very pleased with the size, quality and...

# %%
calendar = pd.read_csv('.../calendar.csv.gz')
calendar.head()
# Out:
#            listing_id        date available   price adjusted_price  \
# 0  652868795892201022  2022-09-15         f  $85.00         $85.00
# 1  652868795892201022  2022-09-16         f  $85.00         $85.00
# 2  652868795892201022  2022-09-17         f  $85.00         $85.00
# 3  652868795892201022  2022-09-18         f  $85.00         $85.00
# 4  652868795892201022  2022-09-19         f  $85.00         $85.00
#
#    minimum_nights  maximum_nights
# 0               1            1125
# 1               1            1125
# 2               1            1125
# 3               1            1125
# 4               1            1125

# %%
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6088202 entries, 0 to 6088201
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            object
#  2   available       object
#  3   price           object
#  4   adjusted_price  object
#  5   minimum_nights  int64
#  6   maximum_nights  int64
# dtypes: int64(3), object(4)
# memory usage: 325.1+ MB

# %%
calendar.date.min()
# Out:
# '2022-09-15'

# %%
neighbourhoods = pd.read_csv('.../neighbourhoods.csv')
neighbourhoods.head()
# Out:
#     neighbourhood_group        neighbourhood
# 0  Charlottenburg-Wilm.            Barstraße
# 1  Charlottenburg-Wilm.  Charlottenburg Nord
# 2  Charlottenburg-Wilm.  Düsseldorfer Straße
# 3  Charlottenburg-Wilm.      Forst Grunewald
# 4  Charlottenburg-Wilm.            Grunewald

# %%
pd.read_json('.../neighbourhoods.geojson')
# Out:
#                   type                                           features
# 0    FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 1    FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 2    FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 3    FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 4    FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# ..                 ...                                                ...
# 135  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 136  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 137  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 138  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 139  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
#
# [140 rows x 2 columns]

# %%
import sqlalchemy as sa

# %%
con = sa.create_engine('sqlite:////.../airbnb.db')

# %%
listings.to_sql('listings', con = con, if_exists = 'replace')
listings_det.to_sql('listings_det', con = con, if_exists = 'replace')
# Out:
# 16680
